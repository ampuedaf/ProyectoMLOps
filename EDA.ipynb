# %%
import gzip
import ast
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df_ED= pd.read_csv('padre_df.csv')

# %%
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44680 entries, 0 to 44679
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item_id                44680 non-null  int64
#  1   suma_playtime_forever  44680 non-null  float64
#  2   user_id                44680 non-null  object
#  3   user_url               44680 non-null  object
#  4   funny                  6232 non-null   object
#  5   posted                 44680 non-null  object
#  6   last_edited            4533 non-null   object
#  7   helpful                44680 non-null  object
#  8   recommend              44680 non-null  bool
#  9   sentiment-analysis     44680 non-null  float64
#  10  publisher              44674 non-null  object
#  11  genres                 44680 non-null  object
#  12  app_name               44680 non-null  object
#  13  title                  44680 non-null  object
# ...

# %%
df_ED.head(3)
# Out:
#    item_id  suma_playtime_forever            user_id  \
# 0       10             17386015.0       Bennysaputra
# 1       10             17386015.0           Monsta45
# 2       10             17386015.0  76561198040188061
#
#                                             user_url funny  \
# 0          http://steamcommunity.com/id/Bennysaputra   NaN
# 1              http://steamcommunity.com/id/Monsta45   NaN
# 2  http://steamcommunity.com/profiles/76561198040...   NaN
#
#                    posted last_edited  \
# 0  Posted August 1, 2015.         NaN
# 1  Posted April 26, 2015.         NaN
# 2    Posted May 18, 2011.         NaN
#
#                                         helpful  recommend  \
# 0                                No ratings yet       True
# 1                                No ratings yet       True
# 2  0 of 2 people (0%) found this review helpful       True
#
#    sentiment-analysis  ...        app_name           title  \
# ...

# %%
df_ED['release_date']=pd.to_datetime(df_ED['release_date'],errors='coerce')
df_ED['release_date']=df_ED['release_date'].dt.year
moda= df_ED['release_date'].mode()[0]
df_ED['release_date']= df_ED['release_date'].fillna(moda)
#df_1_2['release_date'] = df_1_2['release_date'].astype(int)

# %%
fecha = df_ED['release_date']

# %%
fecha = fecha.astype(int)

# %%
df_ED['release_date']= fecha

# %%
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44680 entries, 0 to 44679
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item_id                44680 non-null  int64
#  1   suma_playtime_forever  44680 non-null  float64
#  2   user_id                44680 non-null  object
#  3   user_url               44680 non-null  object
#  4   funny                  6232 non-null   object
#  5   posted                 44680 non-null  object
#  6   last_edited            4533 non-null   object
#  7   helpful                44680 non-null  object
#  8   recommend              44680 non-null  bool
#  9   sentiment-analysis     44680 non-null  float64
#  10  publisher              44674 non-null  object
#  11  genres                 44680 non-null  object
#  12  app_name               44680 non-null  object
#  13  title                  44680 non-null  object
# ...

# %%
df_ED['price'] = pd.to_numeric(df_ED['price'], errors='coerce')



df_ED['price'].fillna(0, inplace=True)

# %%
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44680 entries, 0 to 44679
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item_id                44680 non-null  int64
#  1   suma_playtime_forever  44680 non-null  float64
#  2   user_id                44680 non-null  object
#  3   user_url               44680 non-null  object
#  4   funny                  6232 non-null   object
#  5   posted                 44680 non-null  object
#  6   last_edited            4533 non-null   object
#  7   helpful                44680 non-null  object
#  8   recommend              44680 non-null  bool
#  9   sentiment-analysis     44680 non-null  float64
#  10  publisher              44674 non-null  object
#  11  genres                 44680 non-null  object
#  12  app_name               44680 non-null  object
#  13  title                  44680 non-null  object
# ...

# %%
df_4= pd.read_csv('D:/USUARIO/Desktop/Henry/ProIndi1/df_funcion4.csv')

# %%
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47675 entries, 0 to 47674
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    47675 non-null  object
#  1   app_name   47675 non-null  object
#  2   recommend  47675 non-null  bool
#  3   posted     47675 non-null  int64
# dtypes: bool(1), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
posted = df_4['posted']

# %%
df_ED['posted']= posted

# %%
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44680 entries, 0 to 44679
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item_id                44680 non-null  int64
#  1   suma_playtime_forever  44680 non-null  float64
#  2   user_id                44680 non-null  object
#  3   user_url               44680 non-null  object
#  4   funny                  6232 non-null   object
#  5   posted                 44680 non-null  int64
#  6   last_edited            4533 non-null   object
#  7   helpful                44680 non-null  object
#  8   recommend              44680 non-null  bool
#  9   sentiment-analysis     44680 non-null  float64
#  10  publisher              44674 non-null  object
#  11  genres                 44680 non-null  object
#  12  app_name               44680 non-null  object
#  13  title                  44680 non-null  object
# ...

# %%
df_ED['early_access'] = df_ED['early_access'].replace({True: 1, False: 0})

# %%
df_ED['recommend'] = df_ED['recommend'].replace({True: 1, False: 0})

# %%
df_ED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44680 entries, 0 to 44679
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item_id                44680 non-null  int64
#  1   suma_playtime_forever  44680 non-null  float64
#  2   user_id                44680 non-null  object
#  3   user_url               44680 non-null  object
#  4   funny                  6232 non-null   object
#  5   posted                 44680 non-null  int64
#  6   last_edited            4533 non-null   object
#  7   helpful                44680 non-null  object
#  8   recommend              44680 non-null  int64
#  9   sentiment-analysis     44680 non-null  float64
#  10  publisher              44674 non-null  object
#  11  genres                 44680 non-null  object
#  12  app_name               44680 non-null  object
#  13  title                  44680 non-null  object
# ...

# %%
df_numeric = df_ED.select_dtypes(include=[np.number])

# %%
df_numeric.head()
# Out:
#    item_id  suma_playtime_forever  posted  recommend  sentiment-analysis  \
# 0       10             17386015.0    2015          1                 2.0
# 1       10             17386015.0    2015          1                 1.0
# 2       10             17386015.0    2011          1                 2.0
# 3       10             17386015.0    2014          1                 2.0
# 4       10             17386015.0    2014          1                 2.0
#
#    release_date  price  early_access
# 0          2000   9.99             0
# 1          2000   9.99             0
# 2          2000   9.99             0
# 3          2000   9.99             0
# 4          2000   9.99             0

# %%
corr= df_numeric.corr()

# %%
corr.style.background_gradient()
# Out:
# <style type="text/css">
# #T_f839b_row0_col0, #T_f839b_row1_col1, #T_f839b_row2_col2, #T_f839b_row3_col3, #T_f839b_row4_col4, #T_f839b_row5_col5, #T_f839b_row6_col6, #T_f839b_row7_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f839b_row0_col1, #T_f839b_row0_col3, #T_f839b_row0_col4, #T_f839b_row1_col0, #T_f839b_row1_col2, #T_f839b_row1_col5, #T_f839b_row1_col7, #T_f839b_row3_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f839b_row0_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_f839b_row0_col5 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_f839b_row0_col6, #T_f839b_row1_col6, #T_f839b_row5_col3 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_f839b_row0_col7, #T_f839b_row6_col5 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_f839b_row1_col3 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_f839b_row1_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# ...

# %% [markdown]
# Análisis de la matriz de correlación:
# La variable "item_id" tiene una correlación positiva moderada con "release_date" (0.695588).
# La variable "suma_playtime_forever" tiene una correlación negativa moderada con "posted" (-0.533144).
# La variable "recommend" tiene una correlación positiva moderada con "sentiment-analysis" (0.246838).

# %%
sns.pairplot(df_ED)
sns.set(style="ticks")
# Out:
# c:\Users\USUARIO\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# - Podemos observar que la relación de "price" con "item_id" están sumamente agrupadosa excepto de unos 5 datos outliers con respecto a los precios ("price").
# - En la grafica de "item_id"  con "release_date"  podemos concluir que hubo una mayor frecuencia de actividad entre los años 2005 al 2015.
# - Se confirma  como resultado que la sumatoria de horas jugadas por año estan mas acentuada en los ultimos años, es decir del 2005 en adelante.

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud

# %%
# Concateno todos los registros de "title" en un solo string
text = ' '.join(df_ED["title"].astype(str))

# Creo un objeto WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Grafico el Wordcloud usando matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Analisis de los wordclouds.
# - Algunos de las palabras mas frecuentes en los titulos de juegos coinciden con los juegos recomendados por los usuarios, como los son Counter Strike, Global Offensive, Strike Global, entre otros.

# %%
# Concateno todos los registros de "title" en un solo string
text = ' '.join(df_ED["genres"].astype(str))

# Creo un objeto WordCloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Grafico el Wordcloud usando matplotlib
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
#  En este Wordcloud observamos patrones y tendencias con respecto a lgenero 'Action','Adventure', 'Early Acces', esrto coincide cuando hacemos el tipo de recomendación hecho con machine learning.

# %% [markdown]
# II. Machine Learning

# %% [markdown]
# Vamos hacer todo el proceso para Generar  el dataset requerido para poder hacer el sistema de recomendaciones.

# %%
import gzip
import ast
import json
import pandas as pd
import numpy as np

df_5= pd.read_csv('df_funcion6.csv')

df_5.info()

df_5.head()

vamos a desanidar la columna genres.

def convertir_a_lista(elemento):
    try:
        return ast.literal_eval(elemento)
    except (SyntaxError, ValueError):
        return elemento

df_5['genres'] = df_5['genres'].apply(convertir_a_lista)


ahora hacemos el explode

df_5= df_5.explode('genres')

df_5.info()

ahora hacemos lo mismo para la columna tags

def convertir_a_lista(elemento):
    try:
        return ast.literal_eval(elemento)
    except (SyntaxError, ValueError):
        return elemento

df_5['tags'] = df_5['tags'].apply(convertir_a_lista)

df_5= df_5.explode('tags')

df_5.head()

df_5.reset_index(drop=True, inplace=True)

df_5.head()

df_sin_duplicados = df_5.drop_duplicates(subset=["title"])
df_sin_duplicados.head()

df_sin_duplicados.reset_index(drop=True, inplace=True)

df_sin_duplicados.head(20)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Crear un vectorizador TF-IDF para convertir títulos en vectores numéricos
# Crear una matriz TF-IDF para representar los juegos
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df_sin_duplicados.head()['title'] + ' ' + df_sin_duplicados.head()['tags'] + ' ' + df_sin_duplicados.head()['genres'])

# Calcular la similitud de coseno entre los juegos
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)


# Función definida para el sistema de recomendación item-item:
def recomendacion_juego(title, num_recommendations=20):
    idx = df_sin_duplicados[df_sin_duplicados['title'] == title].index[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    num_recommendations = int(num_recommendations)
    sim_scores = sim_scores[1:num_recommendations+1]  
    game_indices = [i[0] for i in sim_scores]
    resultado3 = {"Juegos recomendados  por  Item-Item ":title}
    diccionario2 = df_sin_duplicados['title'].iloc[game_indices].tolist()
    return resultado3,diccionario2
    

prueba = recomendacion_juego('Counter-Strike')
print(prueba)

# Función definida para el sistema de recomendación user-item:
def recomendacion_usuario(user_id, num_recommendations=5):
    
    # Filtrar el DataFrame para obtener los juegos que le gustan al usuario
    user_likes = df_sin_duplicados[df_sin_duplicados['user_id'] == user_id]
    
    if user_likes.empty:
        return "No se encontraron juegos que le gusten al usuario."

    # Calcular el promedio de las puntuaciones de similitud para los juegos que le gustan al usuario
    avg_similarity_scores = cosine_sim[user_likes.index].mean(axis=0)

    # Obtener los índices de los juegos recomendados ordenados por similitud
    game_indices = avg_similarity_scores.argsort()[::-1]

    # Excluir los juegos que ya le gustan al usuario
    recommended_games = [game for game in game_indices if game not in user_likes.index]

    # Tomar los primeros 'num_recommendations' juegos recomendados
    recommended_games = recommended_games[:num_recommendations]

    # Obtener los títulos de los juegos recomendados
    recommended_titles = df_sin_duplicados.iloc[recommended_games]['title'].tolist()

    return recommended_titles

prueba2 = recomendacion_usuario('TomoeMamiewe')
print(prueba2)

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Crear un vectorizador TF-IDF para convertir títulos en vectores numéricos
# Crear una matriz TF-IDF para representar los juegos
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df_sin_duplicados['title'] + ' ' + df_sin_duplicados['tags'] + ' ' + df_sin_duplicados['genres'])
s
# Calcular la similitud de coseno entre los juegos
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
# Crear el vectorizador TF-IDF
vectorizador = TfidfVectorizer()

# Crear la matriz TF-IDF para representar los juegos
matriz_tfidf = vectorizador.fit_transform(muestra_df['title'])

# Calcular la similitud del coseno entre los juegos
similitud = cosine_similarity(matriz_tfidf)

# Función de recomendación item-item
def recomendacion_juego(id_producto):
    # Obtener el índice del juego ingresado
    indice_juego = muestra_df[muestra_df['title'] == id_producto].index[0]
     # Obtener los valores de similitud del juego ingresado con el resto de juegos
    similitudes = similitud[indice_juego]

    # Obtener los índices de los juegos más similares
    indices_similares = similitudes.argsort()[-6:-1]

    # Obtener los títulos de los juegos recomendados
    juegos_recomendados = muestra_df.loc[indices_similares, 'title'].tolist()

    return juegos_recomendados
